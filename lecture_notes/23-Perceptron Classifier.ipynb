# %%
# %matplotlib inline

# %% [markdown]
# Our dataset is again the iris flower dataset, see https://en.wikipedia.org/wiki/Iris_flower_data_set. Just that you know what these iris flowers are...
#
#
# **Iris Setosa**
# ![iris_setosa](https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Kosaciec_szczecinkowaty_Iris_setosa.jpg/440px-Kosaciec_szczecinkowaty_Iris_setosa.jpg)
#
# **Iris Versicolor**
# ![iris_versicolor](https://upload.wikimedia.org/wikipedia/commons/thumb/4/41/Iris_versicolor_3.jpg/440px-Iris_versicolor_3.jpg)
#
# **Iris Virginica**
# ![iris_virginica](https://upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Iris_virginica.jpg/440px-Iris_virginica.jpg)
#
# ![taxonomy](https://sebastianraschka.com/images/blog/2014/linear-discriminant-analysis/iris_petal_sepal.png)
#
#
#
# In case you did not convert the Excel file with the iris flower dataset to CSV file earlier, you are lucky since you can import it from `sklearn.datasets`. You have to install the correspoonding package.
#
#
# ```bash
# pip install sklearn
# ```
#
# Since `sklearn` depends on `scipy` it might be, that you have to install this dependency too in case you do not already have it.
#
# ```bash
# pip install scipy
# ```

# %% [markdown]
# However, we simplify this dataset a bit and say we are only interested in *iris setosa* and other iris flowers.

# %%
import matplotlib
import matplotlib.pyplot as plt
from sklearn import datasets


iris = datasets.load_iris()
colors = 'bgr'
for idx, name in enumerate(iris.target_names):

    sepal_length = iris.data[iris.target == idx][:,0]
    sepal_width = iris.data[iris.target == idx][:,1]

    plt.scatter(sepal_length, sepal_width, c=colors[idx], label=name)

plt.title('Iris Sepal Characteristics')
plt.xlabel('sepal length')
plt.ylabel('sepal width')

plt.legend()
plt.show()

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
sepal_length = iris.data[iris.target == 0][:,0]
sepal_width = iris.data[iris.target == 0][:,1]
plt.scatter(sepal_length, sepal_width, c='b', label='setosa')

sepal_length = iris.data[iris.target != 0][:,0]
sepal_width = iris.data[iris.target != 0][:,1]
plt.scatter(sepal_length, sepal_width, c='g', label='other')

plt.title('Iris Sepal Characteristics')
plt.xlabel('sepal length')
plt.ylabel('sepal width')

plt.legend()
plt.show()

# %% [markdown]
# # Intro to Perceptrons
#
# Let's say we want to write an artificial intelligence, i.e., a program, that learns out of the given data about sepal length and width, if a given iris flower is an iris setosa or if it is not.
#
# We can do this with a single artificial brain cell, a perceptron. The original paper for Perceptron Learning Algorithm (PLA) is from the 50s.
#
# *"The Perceptron: A Probabilistic Model For Information Storage And Organization in the Brain"* - F. Rosenblatt (December 1958)
# http://www.ling.upenn.edu/courses/Fall_2007/cogs501/Rosenblatt1958.pdf
#
#
# ## A perceptron?
#
# A *perceptron* is a
# > hypothetical nervous system, or machine,...
#
# see the above paper. Or, according to the Oxford Dictionary, *perceptron* is a
# > a computer model or computerized machine devised to represent or simulate the ability of the brain to recognize and discriminate.
#
#
# ![](https://appliedgo.net/media/perceptron/neuron.png)
#
#
#
# To see what is going on in a perceptron, see the animation at https://appliedgo.net/perceptron/ in the section *Inside an artificial neuron*.
#
# That is, we can implement aa activation function and a perceptron in Python as in the following.

# %%
import numpy as np


def activation_function(x):
    if x < 0:
        return -1
    else:
        return 1


rnge = np.linspace(-10.0, 10.0, num=1000)
values = [activation_function(i) for i in rnge]
plt.plot(rnge, values)
plt.axis([-10, 9, -2, 2])
# Out:
# [-10, 9, -2, 2]

# %%
import numpy as np


def perceptron(inp, weights):
    # This is the same as the dot product np.dot(i, w)
    dot_product = sum([i * w for i, w in zip(inp, weights)])
    output = activation_function(dot_product)
    return output

perceptron([1, 2, 3, 4, 5], [1, 1, 2, 1, 1])
# Out:
# 1

# %% [markdown]
# # Perceptrons for Classification
#
# Using our perceptron, we want to have a program which can *predict* -given a pair of sepal length and sepal width- if our flower is an iris setosa or not. That is, we want to have a program that says `setosa` (or `1`) for example for `[5.6, 4.8]` or for `[3.4, 4.1]` and it says `other` (or `-1`) for example for `[5.8, 1.9]` or for `[6.2, 2.4]`. Note that all those examples are "new" flowers, i.e., we did not observe those value combinations on earlier flowers. Additionally, our program should return the correct class labels for flowers, which we already know from the iris flower dataset.

# %%
def predict(inp_vec, weights):
    """
    inp_vec:
        An input vector consisting of sepal length and width
    return:
        A class label, either 1 for 'setosa' or -1 for 'other'
    """
    class_label = perceptron(inp_vec, weights)
    return class_label


weights = [-2.60105969, 3.61349319]

# new flowers
assert predict([5.6, 4.8], weights) == 1
assert predict([3.4, 4.1], weights) == 1
assert predict([5.8, 1.9], weights) == -1
assert predict([6.2, 2.4], weights) == -1

# flowers we already know
assert predict([5.4,  3.9], weights) == 1
assert predict([5.7,  4.4], weights) == 1

# %% [markdown]
# Given the above program, we could say that we are done, no? The program obviously satisfies the requirements described above. However, the question is where do the weights (`weights = [-2.60105969, 3.61349319]`) come from? Here, I have given them to you but where did I get them from?
#
# Actually, they were automatically learned by the program using the Perceptron Learning Algorithm (PLA), which we are going to implement in the following.
#
# To do so, we need a trainings dataset. We will use the one in which we specified which iris flowers are of type setosa or of another type.

# %%
class_labels = np.copy(iris.target)
class_labels[class_labels != 0] = -1
class_labels[class_labels == 0] = 1
#class_labels[class_labels == -1] = 0

trainings_data = [(d[:2], l) for d, l in zip(iris.data, class_labels)]
trainings_data[:10]
# Out:
# [(array([5.1, 3.5]), 1),
#  (array([4.9, 3. ]), 1),
#  (array([4.7, 3.2]), 1),
#  (array([4.6, 3.1]), 1),
#  (array([5. , 3.6]), 1),
#  (array([5.4, 3.9]), 1),
#  (array([4.6, 3.4]), 1),
#  (array([5. , 3.4]), 1),
#  (array([4.4, 2.9]), 1),
#  (array([4.9, 3.1]), 1)]

# %%
from itertools import cycle


def plot_data(data, w_line=(0, 0)):
    """
    data:
        
    """
    # print(data[:10])
    data_points, class_labels = list(zip(*data))
    data_points = np.array(data_points)
    class_labels = np.array(class_labels)

    colors = cycle('bgrcmy')
    for l, col in zip(np.unique(class_labels), colors):
        d =  data_points[class_labels == l]
        x = d[:,0]
        y = d[:,1]
        plt.scatter(d[:,0], d[:,1], c=col, label=l)
    
    if w_line != (0, 0):
        l = np.linspace(0, 8.5)
        m, b = w_line
        plt.plot(l, m * l + b, 'y-', lw=2)

    plt.axis([0, 8.5, 0, 5])
    plt.title('Iris Characteristics')
    plt.xlabel('length')
    plt.ylabel('width')
    plt.legend()

    
plot_data(trainings_data)

# %%
import numpy as np


def pla(training_data, no_iterations=10000, eta=0.5):
    # eta is the learning rate
    # initial_error
    error = np.random.random()
    dim = len(training_data[0][0])
    weights =  np.random.random(dim)
    weight_history = [np.copy(weights)]

    for i in range(no_iterations):
        inp_vec, expected_label = training_data[i % len(training_data)]
        perceptron_output = perceptron(inp_vec, weights)
        error = expected_label - perceptron_output
        # print(error)
        weights += eta * error * inp_vec
        weight_history.append(np.copy(weights))
        
    return weights, weight_history 
        

learned_weights, weight_history = pla(trainings_data)
learned_weights
# Out:
# array([-31.9374306 ,  47.21173739])

# %%
weight_history
# Out:
# [array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([0.4625694 , 0.51173739]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-6.5374306 , -2.68826261]),
#  array([-1.4374306 ,  0.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([3.4625694 , 3.81173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([-3.5374306 ,  0.61173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([1.5625694 , 4.11173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-5.4374306 ,  0.91173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-0.3374306 ,  4.41173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-7.3374306 ,  1.21173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-2.2374306 ,  4.71173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-8.6374306 ,  1.51173739]),
#  array([-3.5374306 ,  5.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([1.3625694 , 8.01173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-5.6374306 ,  4.81173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-0.5374306 ,  8.31173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  array([-7.5374306 ,  5.11173739]),
#  ...]

# %%
# new flowers
print(predict([5.6, 4.8], learned_weights))
print(predict([3.4, 4.1], learned_weights))
print(predict([5.8, 1.9], learned_weights))
print(predict([6.2, 2.4], learned_weights))

# flowers we already know
print(predict([5.4, 3.9], learned_weights))
print(predict([5.7, 4.4], learned_weights))
# Out:
# 1
# 1
# -1
# -1
# 1
# 1

# %% [markdown]
# # What was going on here?
#
# Let's visualize how the weights slice our feature space and how they developed over the iterations...

# %%
def compute_line(weights):
    norm = np.linalg.norm(weights)
    ww = weights / norm
    ww1 = [ww[1], -ww[0]]
    ww2 = [-ww[1] , ww[0]]
                
    # slope and intercept
    m = (ww2[1] - ww1[1]) / (ww2[0] - ww1[0])
    b = ((ww2[0] - ww1[0]) * m) + ww1[1]
    
    return m, b


plot_data(trainings_data, compute_line(learned_weights))

# %% [markdown]
# In the following you see how the weights and thereby the line discriminating our iris flower dataset. See the code that creates the animated Gif in the end of the notebook.
#
# ![weights](./images/animated.gif)

# %% [markdown]
# # We add a bias input...

# %%
import numpy as np


def pla(training_data, no_iterations=10000, w_bias=False, eta=0.5):
    # eta is the learning rate
    # initial_error
    error = np.random.random()
    dim = len(training_data[0][0])
    weights = np.random.random(dim)
    weight_history = [np.copy(weights)]

    if w_bias:
        weights = np.random.random(dim + 1)
        data = np.array(list(zip(*training_data))[0])
        biases = np.ones((data.shape[0], 1))
        training_data_w_bias = np.append(data, biases, axis=1)
        
        training_data = list(zip(training_data_w_bias, 
                                 list(zip(*training_data))[1]))
    
    for i in range(no_iterations):
        inp_vec, expected_label = training_data[i % len(training_data)]
        perceptron_output = perceptron(inp_vec, weights)
        error = expected_label - perceptron_output

        weights += eta * error * inp_vec
        weight_history.append(np.copy(weights))

    return weights, np.array(weight_history)


learned_weights, weight_history = pla(trainings_data, w_bias=True)
learned_weights = learned_weights[:2]
print(learned_weights)


plot_data(trainings_data, compute_line(learned_weights))
# Out:
# [-31.39365713  46.93800065]

# %%
print(predict([5.6, 4.8], learned_weights))
print(predict([3.4, 4.1], learned_weights))
print(predict([5.8, 1.9], learned_weights))
print(predict([6.2, 2.4], learned_weights))

# flowers we already know
print(predict([5.4, 3.9], learned_weights))
print(predict([5.7, 4.4], learned_weights))
# Out:
# 1
# 1
# -1
# -1
# 1
# 1

# %%
def compute_error_rate(data, model):
    data_points, class_labels = list(zip(*data))
    data_points = np.array(data_points)
    class_labels = np.array(class_labels)
    
    errors = np.array([predict(vec, model) for vec in data_points])
    c_falsy_elements = np.sum(errors != class_labels)
    return c_falsy_elements / len(class_labels)


error_rates = [compute_error_rate(trainings_data, i) for i in weight_history]

plt.plot(error_rates)
plt.show()

# %%
from tqdm import tqdm


def pla(training_data, no_iterations=10000, w_bias=False, eta=0.5):
    # eta is the learning rate
    # initial_error
    error = np.random.random()
    dim = len(training_data[0])
    weights = np.random.random(dim)
    weight_history = [np.copy(weights)]
    error_rates = []

    if w_bias:
        weights = np.random.random(dim + 1)
        data = np.array(list(zip(*training_data))[0])
        biases = np.ones((data.shape[0], 1))
        training_data_w_bias = np.append(data, biases, axis=1)
        
        training_data = list(zip(training_data_w_bias, 
                                 list(zip(*training_data))[1]))   
    
    if no_iterations == -1:
        i = 0
        error_rate = 1.0
        while True:
            inp_vec, expected_label = training_data[i % len(training_data)]
            perceptron_output = perceptron(inp_vec, weights)
            error = expected_label - perceptron_output
            
            weights += eta * error * inp_vec
            weight_history.append(np.copy(weights))
            
            error_rate = compute_error_rate(training_data, weights)
            error_rates.append(error_rate)
            if error_rate < 0.01:
                break
            i += 1
        print('Error {} after {} iiterations'.format(error_rate, i))
    else:
        for i in tqdm(range(no_iterations)):
            inp_vec, expected_label = training_data[i % len(training_data)]
            perceptron_output = perceptron(inp_vec, weights)
            error = expected_label - perceptron_output
            
            weights += eta * error * inp_vec
            weight_history.append(np.copy(weights))
            
            error_rate = compute_error_rate(training_data, weights)
            error_rates.append(error_rate)
        
    return weights, np.array(weight_history), error_rates

learned_weights, h, error_rates = pla(trainings_data, no_iterations=-1, w_bias=True)
learned_weights = learned_weights[:2]
print(learned_weights)


plot_data(trainings_data, compute_line(learned_weights))
# Out:
# Error 0.006666666666666667 after 1200 iiterations
# [-5.11010869  7.70439556]

# %%
# compute_error_rate(trainings_data, h[-1])

# error_rates = [compute_error_rate(trainings_data, i) for i in h]

plt.plot(error_rates)
plt.show()

# %% [markdown]
# # Alternative Activation Functions

# %%
from scipy.special import erf


def activation_function(x):
    if x < 0:
        return -1
    else:
        return 1


rnge = np.linspace(-10.0, 10.0, num=1000)
values = [erf(i) for i in rnge]
plt.plot(rnge, values)
plt.axis([-10, 9, -2, 2])

activation_function = erf

# %%
learned_weights, weight_history, error_rates = pla(trainings_data, no_iterations=-1, w_bias=True)
learned_weights = learned_weights[:2]
print(learned_weights)


plot_data(trainings_data, compute_line(learned_weights))
# Out:
# Error 0.006666666666666667 after 18351 iiterations
# [-42.03733329  62.59622624]

# %%
# %%bash
# mkdir data_dump

# %%
def plot_data(data, idx, w_line=(0, 0)):
    plt.clf()
    data_points, class_labels = list(zip(*data))
    data_points = np.array(data_points)
    class_labels = np.array(class_labels)

    colors = cycle('bgrcmy')
    for l, col in zip(np.unique(class_labels), colors):
        d =  data_points[class_labels == l]
        x = d[:,0]
        y = d[:,1]
        plt.scatter(d[:,0], d[:,1], c=col, label=l)
    
    if w_line != (0, 0):
        l = np.linspace(0, 8.5)
        m, b = w_line
        plt.plot(l, m * l + b, 'y-', lw=2)

    plt.axis([0, 8.5, 0, 5])
    plt.title('Iris Characteristics {}'.format(idx))
    plt.xlabel('length')
    plt.ylabel('width')
    plt.legend()
    plt.savefig('./data_dump/p_it{}'.format(idx), dpi=100, bbox_inches='tight')

    
for idx, w in enumerate(weight_history[::80]):
    plot_data(trainings_data, idx, compute_line(w[:2]))

# %%
# %%bash
# ls -ltrh ./data_dump/
# Out:
# total 13056
# -rw-r--r--  1 rhp  staff    18K Apr  9 14:49 p_it2.png
# -rw-r--r--  1 rhp  staff    17K Apr  9 14:49 p_it1.png
# -rw-r--r--  1 rhp  staff    18K Apr  9 14:49 p_it0.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it8.png
# -rw-r--r--  1 rhp  staff    19K Apr  9 14:49 p_it7.png
# -rw-r--r--  1 rhp  staff    18K Apr  9 14:49 p_it6.png
# -rw-r--r--  1 rhp  staff    19K Apr  9 14:49 p_it5.png
# -rw-r--r--  1 rhp  staff    18K Apr  9 14:49 p_it4.png
# -rw-r--r--  1 rhp  staff    19K Apr  9 14:49 p_it3.png
# -rw-r--r--  1 rhp  staff    20K Apr  9 14:49 p_it9.png
# -rw-r--r--  1 rhp  staff    20K Apr  9 14:49 p_it14.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:49 p_it13.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:49 p_it12.png
# -rw-r--r--  1 rhp  staff    20K Apr  9 14:49 p_it11.png
# -rw-r--r--  1 rhp  staff    19K Apr  9 14:49 p_it10.png
# -rw-r--r--  1 rhp  staff    18K Apr  9 14:49 p_it19.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:49 p_it18.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it17.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:49 p_it16.png
# -rw-r--r--  1 rhp  staff    20K Apr  9 14:49 p_it15.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it25.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it24.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it23.png
# -rw-r--r--  1 rhp  staff    20K Apr  9 14:49 p_it22.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:49 p_it21.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it20.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it30.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it29.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it28.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it27.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it26.png
# -rw-r--r--  1 rhp  staff    21K Apr  9 14:49 p_it35.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it34.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it33.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:49 p_it32.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it31.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it41.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it40.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it39.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it38.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it37.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it36.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it47.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it46.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it45.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it44.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it43.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it42.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:49 p_it53.png
# -rw-r--r--  1 rhp  staff    21K Apr  9 14:49 p_it52.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it51.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it50.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it49.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it48.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it59.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it58.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it57.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it56.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it55.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it54.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it65.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it64.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it63.png
# -rw-r--r--  1 rhp  staff    20K Apr  9 14:49 p_it62.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it61.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it60.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it71.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it70.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:49 p_it69.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it68.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it67.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it66.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it77.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:49 p_it76.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it75.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it74.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it73.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it72.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:49 p_it84.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:49 p_it83.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it82.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it81.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it80.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it79.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it78.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:49 p_it89.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it88.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it87.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it86.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:49 p_it85.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it95.png
# -rw-r--r--  1 rhp  staff    21K Apr  9 14:50 p_it94.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it93.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it92.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:50 p_it91.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it90.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it99.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it98.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it97.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it96.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it101.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it100.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it107.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it106.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it105.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it104.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it103.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it102.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it113.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it112.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it111.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it110.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it109.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it108.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it119.png
# -rw-r--r--  1 rhp  staff    21K Apr  9 14:50 p_it118.png
# -rw-r--r--  1 rhp  staff    21K Apr  9 14:50 p_it117.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:50 p_it116.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it115.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it114.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it125.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:50 p_it124.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:50 p_it123.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it122.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it121.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it120.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it131.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it130.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it129.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it128.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it127.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it126.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it136.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it135.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it134.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it133.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it132.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it142.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it141.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it140.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it139.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it138.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it137.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it147.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it146.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it145.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it144.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it143.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it153.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it152.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it151.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it150.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it149.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it148.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it159.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it158.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it157.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it156.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it155.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it154.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it165.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it164.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it163.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it162.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it161.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it160.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it171.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it170.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it169.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it168.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it167.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it166.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it177.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it176.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it175.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it174.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:50 p_it173.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it172.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it183.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it182.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it181.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it180.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it179.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it178.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it189.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:50 p_it188.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:50 p_it187.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it186.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it185.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it184.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it194.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it193.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it192.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it191.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it190.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it200.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it199.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it198.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it197.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it196.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it195.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it206.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it205.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it204.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it203.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:50 p_it202.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it201.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it212.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it211.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it210.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it209.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it208.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it207.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it218.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it217.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it216.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it215.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it214.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it213.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it224.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it223.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it222.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it221.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it220.png
# -rw-r--r--  1 rhp  staff    21K Apr  9 14:50 p_it219.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it230.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it229.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it228.png
# -rw-r--r--  1 rhp  staff    21K Apr  9 14:50 p_it227.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it226.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it225.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it236.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it235.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it234.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it233.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it232.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it231.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it242.png
# -rw-r--r--  1 rhp  staff    22K Apr  9 14:50 p_it241.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it240.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it239.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it238.png
# -rw-r--r--  1 rhp  staff    23K Apr  9 14:50 p_it237.png
# -rw-r--r--  1 rhp  staff    20K Apr  9 14:50 p_it248.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it247.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it246.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it245.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it244.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it243.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it251.png
# -rw-r--r--  1 rhp  staff    24K Apr  9 14:50 p_it250.png
# -rw-r--r--  1 rhp  staff    25K Apr  9 14:50 p_it249.png

# %%
# if you want to have this piece of code working on your VM run
# sudo apt-get install -y imagemagick
import os
import subprocess

basedir = './data_dump/'
pngs = [pl for pl in os.listdir(basedir) if pl.endswith('png')]
sorted_pngs = sorted(pngs, key=lambda a:int(a.split('p_it')[1][:-4]), reverse=False)
#basepng = pngs[0][:-8]
pngs = [os.path.join(basedir, png) for png in sorted_pngs]
pngs_str = ' '.join(pngs)
cmd = ("convert -delay 10 {} ./data_dump/animated.gif".format(pngs_str)).split()
proc = subprocess.Popen(cmd, stdin = subprocess.PIPE, stdout = subprocess.PIPE)
out, err = proc.communicate()

if not err:
    for png in pngs:
        os.remove(png)

# %% [markdown]
# # Learning Observed
#
# ![weights](./data_dump/animated.gif)

# %% [markdown]
# # Exercise
#
#   * Implement the Perceptron Learning Algorithm (PLA) similarly as demonstrated above for the petal length and petal width.

# %%
petal_length = transposed_data[2]
petal_width = transposed_data[3]


# The following lines are only to generate a list of labels, which may 
# only be numbers
labels = list(set(species))
number_labels = [labels.index(s) for s in species]
colors = ['red', 'green', 'blue']

plt.scatter(petal_length, petal_width, marker="o", 
            c=number_labels, cmap=matplotlib.colors.ListedColormap(colors))

# %% [markdown]
#   * Adapt the PLA algorithm to work on another dataset. For example, create a dataset with checkmarks and crosses that may appear on paper forms and train your perceptron to discriminate those.

# %% [markdown]
#   * Implement the Perceptron Learning Algorithm (PLA) similarly as demonstrated above for the following three-dimensional dataset.

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets.samples_generator import make_blobs


centers = [[2, 1, 0], [0, -1, -1]]
data_3d, _ = make_blobs(n_samples=2500, centers=centers, cluster_std=0.37)
x, y, z = data_3d[:,0], data_3d[:,1], data_3d[:,2]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, linewidth=0.2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # What else can I do with a single Perceptron?
#
# For example, winning Flappy Bird. It will likely become quickly better than you!
#
# But note, this neural network is not trained as described above -with gradient descent-. Instead it uses a genetic algorithms to find new weights for neuronal networks of future generations. That is, use some of the best individuals. Some randomly generated ones and some created by breeding from existing individuals.
#
# https://github.com/xviniette/FlappyLearning

# %%
from IPython.display import IFrame
IFrame('http://xviniette.github.io/FlappyLearning/', width=550, height=600)
# Out:
#         <iframe
#             width="550"
#             height="600"
#             src="http://xviniette.github.io/FlappyLearning/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Cleaned up version for teaching!
# PLA -- Perceptron Learning Algorithm
# https://blog.dbrgn.ch/2013/3/26/perceptrons-in-python/
# from numpy import array, dot, random
import numpy as np
import random
import math
import matplotlib.pyplot as plt



class Perceptron():

    def __init__(self, training_data, no_iterations=10000):
        # we fill our initial weights wit random numbers
        # vector w looks for example like: [0.9, 0.08]
        self.w = np.array([random.random() for i in range(2)])
        self.errors = []
        # eta is the learning rate...
        self.eta = 0.05
        self.no_iterations = no_iterations
        self.iter_no = 0
        self._lines = []
        # zip together the training data, it will have the form:
        # [((meassured_length, meassured_width), label), ...]
        self.training_data = training_data
        
        # self._plt = self._plot_data()
                
    def unit_step(self, x):
        if x < 0:
            return -1
        else:
            return 1

    def pla(self):
        iteration = 0
        error = random.random()
        # for x, expected in training_data * 100:
        for i in range(self.no_iterations):
        # while error != 0 or iteration > self.no_iterations:
        # while iteration > self.no_iterations:
            # idx = random.choice(range(len(training_data) - 1))
            x, expected = training_data[i % len(training_data)]
            x = np.array(x)
            result = np.dot(self.w, x)

            error = expected - self.unit_step(result)
            self.errors.append(error)
            self.w += self.eta * error * x
            self.iter_no = i
            self.plot_all(save_img=True, from_training=True)
            
    def predict(self, meassured_length_width_pair):
        x = np.array(meassured_length_width_pair)
        result = np.dot(self.w, meassured_length_width_pair)
        found_class = self.unit_step(result)
        return found_class

    def _plot_line(self):
        # Eukledian norm
        # norm = math.sqrt(self.w[0] ** 2 + self.w[1] ** 2)
        norm = np.linalg.norm(self.w)
        
        ww = self.w / norm
        
        ww1 = [ww[1], -ww[0]]
        ww2 = [-ww[1] , ww[0]]
        
        l = np.linspace(-10,10)
        
        # slope and intercept
        m = (ww2[1] - ww1[1]) / (ww2[0] - ww1[0])
        b = ((ww2[0] - ww1[0]) * m) + ww1[1]
        
        plt.plot(l, m * l + b, 'y-', lw=3)
        
        return plt
    
    def _plot_data(self, colors=['red', 'green']):
        plt.xlabel('sepal length')
        plt.ylabel('sepal width')

        data, label = list(zip(*self.training_data))
        width, length = list(zip(*data))
        
        plt.scatter(width, length , marker="o", c=label, 
                    cmap=matplotlib.colors.ListedColormap(colors))
        plt.axis([4, 8.5, 1.5, 5])
        
        return plt
    
    def _assemble_plot(self, save_img=False):
        if self.iter_no != 0:
            msg = 'Iris Characteristics (Iteration {})'.format(
                self.iter_no)
        else:
            msg = 'Iris Characteristics'
        # plt.figure(self.iter_no + 1)
        plt.clf()
        plt.title(msg)
        self._plot_data()
        self._plot_line()
        
        if save_img:
            self._save_plot()
            
    def plot_all(self, save_img=False, from_training=False):
        
        if not from_training:
            self._assemble_plot(save_img=save_img)
            plt.figure(self.iter_no)
        else:
            if self.iter_no % 100 == 0:
                self._assemble_plot(save_img=save_img)

        return plt
    
    def _save_plot(self):            
        plt.savefig('./data_dump/p_it{}'.format(self.iter_no), 
                     dpi=200, bbox_inches='tight')



training_data = list(zip(zip(sepal_length, sepal_width), 
                         bin_number_labels))
        
p = Perceptron(training_data, no_iterations=6000)
p.pla()
print(p.w)
p.plot_all()
# [-2.34181064  3.39946769]
# Out:
# [-2.60105969  3.61349319]
# <module 'matplotlib.pyplot' from '/usr/lib/python3/dist-packages/matplotlib/pyplot.py'>
